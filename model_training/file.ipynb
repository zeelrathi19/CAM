# %%
from ultralytics import YOLO

#load model
model = YOLO("yolo11n-seg.pt")

#train the model
train_results= model.train(
    data = "tyre_seg//data.yaml",
    epochs = 100,
    imgsz = 640,
    device = "cpu",
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.248 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.240 🚀 Python-3.13.1 torch-2.9.1 CPU (Apple M2)
# ...

# %%
model = YOLO('best.pt')
results = model("wb_test.jpeg")
results[0].show()
# Out:
# image 1/1 /Users/himanshuthacker/Projects/CAM/model_training/wb_test.jpeg: 384x640 5 tyres, 67.3ms
# Speed: 3.4ms preprocess, 67.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
